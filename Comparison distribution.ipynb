# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the two Excel files into Pandas dataframes
td_params_df = pd.read_excel('TD parameters.xlsx')
asd_params_df = pd.read_excel('ASD parameters.xlsx')

# Create a list of column names to compare
col_names = ['Transition rate from saccade to fixation', 
             'Transition rate from fixation to saccade', 
             'Fixation velocities mean', 
             'Fixation velocities standard deviation', 
             'Saccade velocities mean', 
             'Saccade velocities standard deviation']

# Create subplots for each column
fig, axs = plt.subplots(len(col_names), 2, figsize=(15, 20))

# Loop through the column names and compare their distributions
for i, col_name in enumerate(col_names):
    # Get the data for the current column in both dataframes
    td_data = td_params_df[col_name].iloc[1:]
    asd_data = asd_params_df[col_name].iloc[1:]
    
    # Plot the data as histograms in the left subplot
    axs[i, 0].hist(td_data, alpha=0.5, label='TD')
    axs[i, 0].hist(asd_data, alpha=0.5, label='ASD')
    
    # Add a title and legend to the left subplot
    axs[i, 0].set_title(col_name)
    axs[i, 0].legend()
    
    # Plot the data as density plots in the right subplot
    sns.kdeplot(td_data, ax=axs[i, 1], label='TD')
    sns.kdeplot(asd_data, ax=axs[i, 1], label='ASD')
    
    # Add a title and legend to the right subplot
    axs[i, 1].set_title(col_name)
    axs[i, 1].legend()
    
# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font size for the plot
rcParams['font.size'] = 18

# Load the two Excel files into Pandas dataframes
td_params_df = pd.read_excel('TD parameters.xlsx')
asd_params_df = pd.read_excel('ASD parameters.xlsx')

# Create a list of column names to compare
col_names = ['Transition rate from saccade to fixation', 
             'Transition rate from fixation to saccade', 
             'Fixation velocities mean', 
             'Fixation velocities standard deviation', 
             'Saccade velocities mean', 
             'Saccade velocities standard deviation']

# Loop through the column names and create a separate plot for each column
for col_name in col_names:
    # Get the data for the current column in both dataframes
    td_data = td_params_df[col_name].iloc[1:]
    asd_data = asd_params_df[col_name].iloc[1:]
    
    # Create a new plot
    fig, ax = plt.subplots(figsize=(8, 6))
    
    # Plot the data as density plots
    sns.kdeplot(td_data, ax=ax, label='TD')
    sns.kdeplot(asd_data, ax=ax, label='ASD')
    
    # Add a title and legend to the plot
    
    ax.legend()
    
    # Set the font size of the axis labels
    ax.set_xticklabels(ax.get_xticklabels(), fontsize=18)
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
    
    # Save the plot as an image
    plt.savefig(f'{col_name}.png')
    
    # Show the plot
    plt.show()
# Out:
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=18)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2413277474.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=18)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font size for the plot
rcParams['font.size'] = 18

# Load the two Excel files into Pandas dataframes
df_td = pd.read_excel('TD parameters.xlsx')
df_asd= pd.read_excel('ASD parameters.xlsx')

# Create a list of column names to compare
td_data = df_td['Transition rate from saccade to fixation']
asd_data=df_asd['Transition rate from saccade to fixation']

td_mean = td_data.mean()
td_std = td_data.std()
asd_mean = asd_data.mean()
asd_std = asd_data.std()

# Create a new plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the data as density plots
sns.kdeplot(td_data, label='TD', color='blue')
sns.kdeplot(asd_data, label='ASD', color='orange')

# Add vertical lines for the mean of each distribution
ax.axvline(td_mean, color='blue', linestyle='--', label=f'TD Mean: {td_mean:.2f}\nTD SD: {td_std:.2f}')
ax.axvline(asd_mean, color='orange', linestyle='--', label=f'ASD Mean: {asd_mean:.2f}\nASD SD: {asd_std:.2f}')

# Move the legend to the left side of the plot
ax.legend(loc='upper left', fontsize=14)

# Set the font size of the axis labels
ax.set_xlabel('Transition rate from saccade to fixation', fontsize=16)
ax.set_ylabel('Density', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# Save the plot as an image
plt.savefig('distributions.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/1723884242.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/1723884242.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font size for the plot
rcParams['font.size'] = 18

# Load the two Excel files into Pandas dataframes
df_td = pd.read_excel('TD parameters.xlsx')
df_asd= pd.read_excel('ASD parameters.xlsx')

# Create a list of column names to compare
td_data = df_td['Transition rate from fixation to saccade']
asd_data=df_asd['Transition rate from fixation to saccade']

td_mean = td_data.mean()
td_std = td_data.std()
asd_mean = asd_data.mean()
asd_std = asd_data.std()

# Create a new plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the data as density plots
sns.kdeplot(td_data, label='TD', color='blue')
sns.kdeplot(asd_data, label='ASD', color='orange')

# Add vertical lines for the mean of each distribution
ax.axvline(td_mean, color='blue', linestyle='--', label=f'TD Mean: {td_mean:.2f}\nTD SD: {td_std:.2f}')
ax.axvline(asd_mean, color='orange', linestyle='--', label=f'ASD Mean: {asd_mean:.2f}\nASD SD: {asd_std:.2f}')

# Move the legend to the left side of the plot
ax.legend(loc='upper right', fontsize=14)

# Set the font size of the axis labels
ax.set_xlabel('Transition rate from fixation to saccade', fontsize=16)
ax.set_ylabel('Density', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# Save the plot as an image
plt.savefig('distributions.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/1565812588.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/1565812588.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font size for the plot
rcParams['font.size'] = 18

# Load the two Excel files into Pandas dataframes
df_td = pd.read_excel('TD parameters.xlsx')
df_asd= pd.read_excel('ASD parameters.xlsx')

# Create a list of column names to compare
td_data = df_td['Fixation velocities mean']
asd_data=df_asd['Fixation velocities mean']

td_mean = td_data.mean()
td_std = td_data.std()
asd_mean = asd_data.mean()
asd_std = asd_data.std()

# Create a new plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the data as density plots
sns.kdeplot(td_data, label='TD', color='blue')
sns.kdeplot(asd_data, label='ASD', color='orange')

# Add vertical lines for the mean of each distribution
ax.axvline(td_mean, color='blue', linestyle='--', label=f'TD Mean: {td_mean:.2f}\nTD SD: {td_std:.2f}')
ax.axvline(asd_mean, color='orange', linestyle='--', label=f'ASD Mean: {asd_mean:.2f}\nASD SD: {asd_std:.2f}')

# Move the legend to the left side of the plot
ax.legend(loc='upper left', fontsize=14)

# Set the font size of the axis labels
ax.set_xlabel('Fixation velocities mean', fontsize=16)
ax.set_ylabel('Density', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# Save the plot as an image
plt.savefig('distributions.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/808671786.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/808671786.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font size for the plot
rcParams['font.size'] = 18

# Load the two Excel files into Pandas dataframes
df_td = pd.read_excel('TD parameters.xlsx')
df_asd= pd.read_excel('ASD parameters.xlsx')

# Create a list of column names to compare
td_data = df_td['Fixation velocities standard deviation']
asd_data=df_asd['Fixation velocities standard deviation']

td_mean = td_data.mean()
td_std = td_data.std()
asd_mean = asd_data.mean()
asd_std = asd_data.std()

# Create a new plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the data as density plots
sns.kdeplot(td_data, label='TD', color='blue')
sns.kdeplot(asd_data, label='ASD', color='orange')

# Add vertical lines for the mean of each distribution
ax.axvline(td_mean, color='blue', linestyle='--', label=f'TD Mean: {td_mean:.2f}\nTD SD: {td_std:.2f}')
ax.axvline(asd_mean, color='orange', linestyle='--', label=f'ASD Mean: {asd_mean:.2f}\nASD SD: {asd_std:.2f}')

# Move the legend to the left side of the plot
ax.legend(loc='upper right', fontsize=14)

# Set the font size of the axis labels
ax.set_xlabel('Fixation velocities standard deviation', fontsize=16)
ax.set_ylabel('Density', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# Save the plot as an image
plt.savefig('distributions.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/822270690.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/822270690.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font size for the plot
rcParams['font.size'] = 18

# Load the two Excel files into Pandas dataframes
df_td = pd.read_excel('TD parameters.xlsx')
df_asd= pd.read_excel('ASD parameters.xlsx')

# Create a list of column names to compare
td_data = df_td['Saccade velocities mean']
asd_data=df_asd['Saccade velocities mean']

td_mean = td_data.mean()
td_std = td_data.std()
asd_mean = asd_data.mean()
asd_std = asd_data.std()

# Create a new plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the data as density plots
sns.kdeplot(td_data, label='TD', color='blue')
sns.kdeplot(asd_data, label='ASD', color='orange')

# Add vertical lines for the mean of each distribution
ax.axvline(td_mean, color='blue', linestyle='--', label=f'TD Mean: {td_mean:.2f}\nTD SD: {td_std:.2f}')
ax.axvline(asd_mean, color='orange', linestyle='--', label=f'ASD Mean: {asd_mean:.2f}\nASD SD: {asd_std:.2f}')

# Move the legend to the left side of the plot
ax.legend(loc='upper left', fontsize=14)

# Set the font size of the axis labels
ax.set_xlabel('Saccade velocities mean', fontsize=16)
ax.set_ylabel('Density', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# Save the plot as an image
plt.savefig('distributions.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2734696958.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/2734696958.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font size for the plot
rcParams['font.size'] = 18

# Load the two Excel files into Pandas dataframes
df_td = pd.read_excel('TD parameters.xlsx')
df_asd= pd.read_excel('ASD parameters.xlsx')

# Create a list of column names to compare
td_data = df_td['Saccade velocities standard deviation']
asd_data=df_asd['Saccade velocities standard deviation']

td_mean = td_data.mean()
td_std = td_data.std()
asd_mean = asd_data.mean()
asd_std = asd_data.std()

# Create a new plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the data as density plots
sns.kdeplot(td_data, label='TD', color='blue')
sns.kdeplot(asd_data, label='ASD', color='orange')

# Add vertical lines for the mean of each distribution
ax.axvline(td_mean, color='blue', linestyle='--', label=f'TD Mean: {td_mean:.2f}\nTD SD: {td_std:.2f}')
ax.axvline(asd_mean, color='orange', linestyle='--', label=f'ASD Mean: {asd_mean:.2f}\nASD SD: {asd_std:.2f}')

# Move the legend to the left side of the plot
ax.legend(loc='upper left', fontsize=14)

# Set the font size of the axis labels
ax.set_xlabel('Saccade velocities standard deviation', fontsize=16)
ax.set_ylabel('Density', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)

# Save the plot as an image
plt.savefig('distributions.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/372033439.py:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=14)
# /var/folders/vk/zw9gkbl92b1d62br4mrx1ff00000gn/T/ipykernel_2230/372033439.py:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(), fontsize=14)
